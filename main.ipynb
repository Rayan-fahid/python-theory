# %% [markdown]
# # Cicli
#
# ## sottotitolo

# %%
print("prova")
# Out:
# prova

# %% [markdown]
# ## while

# %% [markdown]
# # PROVA
# $4X$

# %% [markdown]
# # ESERCIZI

# %% [markdown]
# ## esercizio 2

# %%
studenti=[]
studenti_classe=["nome1","nome2","nome3","nome4","nome5"]
for i in range(5):
    nomi=input("inserisci i nomi degli studenti")
    if nomi in studenti:
         print("questo studente non va inserito nella classe")
    elif nomi in studenti_classe and nomi not in studenti:
        studenti.append(nomi)
print(studenti)
print(studenti_classe)
# Out:
# questo studente non va inserito nella classe
# questo studente non va inserito nella classe
# ['nome1', 'nome2']
# ['nome1', 'nome2', 'nome3', 'nome4', 'nome5']

# %% [markdown]
# ## esercizio 3

# %%
import random
numeri=[]
for x in range (10):
    numeri_casuali=random.randint(1,5)
    numeri.append(numeri_casuali)
print(numeri)
numeri.reverse()
print(numeri)
# Out:
# [3, 5, 4, 3, 2, 1, 5, 2, 5, 3]
# [3, 5, 2, 5, 1, 2, 3, 4, 5, 3]

# %% [markdown]
# ## esercizio 4

# %%
import random
import math
numeri=[]
N=int(input("inserisci un numero"))
for c in range (N):
    casuale=random.randint(1,20)
    numeri.append(casuale)
    stamp(numeri)
    for i in range (len(numeri)):
        print(numeri[i]**2)
# Out:
# 144
# 144
# 1
# 144
# 1
# 36

# %% [markdown]
# ## esercizio 5

# %%
import random

# Creiamo una lista vuota per contenere i numeri
numeri_casuali = []

# Generiamo 10 numeri interi casuali (ad esempio tra 1 e 50) e li salviamo nella lista
for i in range(10):
    numero = random.randint(1, 50)
    numeri_casuali.append(numero)

# Stampiamo la lista originale per vedere i numeri generati
print("Lista originale generata casualmente:")
print(numeri_casuali)
print("-" * 40)

# Scorriamo la lista usando gli indici perché dobbiamo MODIFICARE i valori interni
for i in range(len(numeri_casuali)):
    # Verifichiamo se il numero nella posizione 'i' è dispari
    if numeri_casuali[i] % 2 != 0:
        # Se è dispari, raddoppiamo il suo valore direttamente nella lista
        numeri_casuali[i] = numeri_casuali[i] * 2

# Stampiamo la lista modificata
print("Lista con i soli valori dispari raddoppiati:")
print(numeri_casuali)

# %% [markdown]
# ## esercizio 6

# %%
import random
numeri=[]
N=int(input("inserisci un numero:  "))
for x in range (N):
    numeri_casuali=random.randint(1,20)
    numeri.append(numeri_casuali)
print(numeri)
somma=0
for numero in numeri:
    somma=somma+numero
print(somma)
# Out:
# [17, 2]
# 19

# %% [markdown]
# ## esercizio 7

# %%
import random
numeri=[]
somma1=0
somma2=0
N=int(input("inserisci un numero:  "))
for x in range (N):
    numeri_casuali=random.randint(-20,20)
    numeri.append(numeri_casuali)
    if numeri_casuali > 0:
            somma1 = somma1 + numeri_casuali
    elif numeri_casuali < 0:
        somma2 = somma2 + numeri_casuali
print(numeri)
print(somma1)
print(somma2)
# Out:
# [-19, 15, -16]
# 15
# -35

# %% [markdown]
# ## esercizio 8

# %%
import random
numeri=[]
pari=[]
dispari=[]
N=int(input("inserisci un numero:  "))
for x in range (N):
    numeri_casuali=random.randint(1,10)
    numeri.append(numeri_casuali)
    if numeri_casuali %2==0:
            pari.append(numeri_casuali)
    elif numeri_casuali %2 !=0:
        dispari.append(numeri_casuali)
print(numeri)
print(pari)
print(dispari)
# Out:
# [9, 6, 1, 2, 5]
# [6, 2]
# [9, 1, 5]

# %% [markdown]
# ## esercizio 9

# %%
numeri=[]
asterisco=""
for x in range (3):
    numero=int(input("inserisci i 3 numeri per fare l'istogramma:  "))
    numeri.append(numero)
for x in numeri:
    print(x*"*")
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[99], line 7
#       3 for x in range (3):
#       4     numero=int(input("inserisci i 3 numeri per fare l'istogramma:  "))
#       5     numeri.append(numero)
#       6 for x in numeri:
# ----> 7     print(x*"*")
#
# OverflowError: cannot fit 'int' into an index-sized integer

# %% [markdown]
# ## esercizio 10

# %%
import random
numeri=[]
for x in range (20):
    numeri_casuali=random.randint(1,100)
    numeri.append(numeri_casuali)
print(numeri)
massimo=numeri[0]
for numero in numeri:
    if numero>massimo:
        massimo=numero
print(massimo)
# Out:
# [22, 96, 99, 87, 32, 4, 76, 8, 94, 20, 12, 13, 81, 76, 95, 47, 79, 70, 41, 28]
# 99

# %% [markdown]
# ## esercizio 11

# %%
import random
numeri=[]
for x in range (10):
    numero_casuale=random.randint(1,10)
    numeri.append(numero_casuale)
prodotto=1
for numero in numeri:
    prodotto=prodotto*numero
print(numeri)
print(prodotto)
# Out:
# [8, 3, 9, 3, 3, 6, 5, 3, 9, 6]
# 9447840

# %% [markdown]
# ## esercizio 12

# %%
import random
numeri=[]
for x in range (10):
    numero_casuale=random.randint(1,10)
    numeri.append(numero_casuale)
denominatore=len(numeri)
somma=0
for numero in numeri:
    somma=numero+somma
risultato=somma/denominatore
print(numeri)
print(somma)
print(denominatore)
print(risultato)
# Out:
# [2, 5, 5, 9, 9, 6, 6, 10, 9, 7]
# 68
# 10
# 6.8
